# %% [markdown]
# <a href="https://colab.research.google.com/github/anoojsarvankar/stock-price-prediction/blob/master/Stock_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Dataset to colab cloud
# Download CSV files from NSE or Yahoo Finance Websites and Upload it to Colab in the following manner.

# %%
# from google.colab import files
# files.upload()
# Out:
#      <input type="file" id="files-bca5531a-e30b-4cfb-b0df-a40fdfeb65ef" name="files[]" multiple disabled />
#      <output id="result-bca5531a-e30b-4cfb-b0df-a40fdfeb65ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ICICIBANK.NS.csv to ICICIBANK.NS.csv
# ...

# %% [markdown]
# # Using the imported File and analysis of data
# Currently ICICI BANK data for the span of 2 years is imported and is to be examined.

# %%
import pandas as pd
ICdata=pd.read_csv("https://drive.google.com/file/d/1CZqPh7xFY2WIIXNgutEtTiVOTJGtY5Ak/view?usp=sharing")
ICdata.sample(5)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-6b928656c0c6> in <module>()
#       1 import pandas as pd
# ----> 2 ICdata=pd.read_csv("https://drive.google.com/file/d/1CZqPh7xFY2WIIXNgutEtTiVOTJGtY5Ak/view?usp=sharing")
#       3 ICdata.sample(5)
#
# ...

# %%
def null_table(dataset):
  print("Dataset")
  print(pd.isnull(dataset).sum()) 

null_table(ICdata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1ff7c2542cce> in <module>()
#       3   print(pd.isnull(dataset).sum())
#       4
# ----> 5 null_table(ICdata)
#
# NameError: name 'ICdata' is not defined
